# %% [markdown]
# # Day 23 - Amphipod

# %% [markdown]
# Start:
#
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #B#C#A#C#
#   #########
# ```
#
# Step 1: (9 energy)
#
# ```
# #############
# #A..........#
# ###D#D#B#.###
#   #B#C#A#C#
#   #########
# ```
#
# Step 2: (+300e = 309e)
#
# ```
# #############
# #A........C.#
# ###D#D#B#.###
#   #B#C#A#.#
#   #########
# ```
#
# Step 3: (+7000e = 7309e)
# ```
# #############
# #A........C.#
# ###D#.#B#.###
#   #B#C#A#D#
#   #########
# ```
#
# Step 4: (+8000e = 15309e)
# ```
# #############
# #A........C.#
# ###.#.#B#D###
#   #B#C#A#D#
#   #########
# ```
#
# Step 5: (+20e = 15329e)
# ```
# #############
# #A......B.C.#
# ###.#.#.#D###
#   #B#C#A#D#
#   #########
# ```
#
# Step 6: (+7e = 15336e)
# ```
# #############
# #AA.....B.C.#
# ###.#.#.#D###
#   #B#C#.#D#
#   #########
# ```
#
# Step 7: (+600e = 15936e)
# ```
# #############
# #AA.....B.C.#
# ###.#.#.#D###
#   #B#.#C#D#
#   #########
# ```
#
# Step 7: (+60e = 15996e)
# ```
# #############
# #AA.....B.C.#
# ###.#.#.#D###
#   #.#B#C#D#
#   #########
# ```
#
# Step 8: (+40e = 16036e)
# ```
# #############
# #AA.......C.#
# ###.#B#.#D###
#   #.#B#C#D#
#   #########
# ```
#
# Step 9: (+400e = 16436e)
# ```
# #############
# #AA.........#
# ###.#B#C#D###
#   #.#B#C#D#
#   #########
# ```
#
# Step 10: (+3e = 16439e)
# ```
# #############
# #A..........#
# ###.#B#C#D###
#   #A#B#C#D#
#   #########
# ```
#
# Step 11: (+3e = 16442e)
# ```
# #############
# #...........#
# ###A#B#C#D###
#   #A#B#C#D#
#   #########
# ```

# %% [markdown]
# ## Attempt 2
#
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #B#C#A#C#
#   #########
# ```
#
# 2: (8e)
#
# ```
# #############
# #.A.........#
# ###D#D#B#.###
#   #B#C#A#C#
#   #########
# ```
#
# 3: (300e = 308)
# ```
# #############
# #.A.......C.#
# ###D#D#B#.###
#   #B#C#A#.#
#   #########
# ```
#
# 4: (7000 = 7308)
# ```
# #############
# #.A.......C.#
# ###D#.#B#.###
#   #B#C#A#D#
#   #########
# ```
#
# 5: (8000 = 15 308)
# ```
# #############
# #.A.......C.#
# ###.#.#B#D###
#   #B#C#A#D#
#   #########
# ```
#
# 6: (40 = 15 348)
# ```
# #############
# #.A.B.....C.#
# ###.#.#.#D###
#   #B#C#A#D#
#   #########
# ```
#
# 7: (3 = 15 351)
# ```
# #############
# #.A.B...A.C.#
# ###.#.#.#D###
#   #B#C#.#D#
#   #########
# ```
#
# 8: (600 = 15 951)
# ```
# #############
# #.A.B...A.C.#
# ###.#.#.#D###
#   #B#.#C#D#
#   #########
# ```
#
# 9: (30 = 15 981)
# ```
# #############
# #.A.....A.C.#
# ###.#.#.#D###
#   #B#B#C#D#
#   #########
# ```
#
# 10: (50 = 16 031)
# ```
# #############
# #.A.....A.C.#
# ###.#B#.#D###
#   #.#B#C#D#
#   #########
# ```
#
# 11: (3 = 16 034)
# ```
# #############
# #.......A.C.#
# ###.#B#.#D###
#   #A#B#C#D#
#   #########
# ```
#
# 12: (6 = 16 044)
# ```
# #############
# #.........C.#
# ###A#B#.#D###
#   #A#B#C#D#
#   #########
# ```
#
# 13: (400 = 16 444)
# ```
# #############
# #...........#
# ###A#B#C#D###
#   #A#B#C#D#
#   #########
# ```

# %% [markdown]
# ## Attempt 3
#
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #B#C#A#C#
#   #########
# ```
#
# 1: 9
# ```
# #############
# #A..........#
# ###D#D#B#.###
#   #B#C#A#C#
#   #########
# ```
#
# 2: 60
#
# ```
# #############
# #AB.........#
# ###D#D#.#.###
#   #B#C#A#C#
#   #########
# ```
#
# 3: 5
# ```
# #############
# #AB.......A.#
# ###D#D#.#.###
#   #B#C#.#C#
#   #########
# ```
#
# 4: 600
# ```
# #############
# #AB.......A.#
# ###D#D#.#.###
#   #B#C#C#.#
#   #########
# ```
#
# 5: (optimal double D = 15k)
# ```
# #############
# #AB.......A.#
# ###.#.#.#D###
#   #B#C#C#D#
#   #########
# ```
#
# 6: 500
# ```
# #############
# #AB.......A.#
# ###.#.#C#D###
#   #B#.#C#D#
#   #########
# ```
#
# 7: double B: 60 + 40 = 100
# ```
# #############
# #A........A.#
# ###.#B#C#D###
#   #.#B#C#D#
#   #########
# ```
#
# 8: double A:  12
# ```
# #############
# #...........#
# ###A#B#C#D###
#   #A#B#C#D#
#   #########
# ```
#
# sum = 16286

# %% [markdown]
# ## Attempt 3
#
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #B#C#A#C#
#   #########
# ```
#
# 1: 9
# ```
# #############
# #A..........#
# ###D#D#B#.###
#   #B#C#A#C#
#   #########
# ```
#
# 2: 40
#
# ```
# #############
# #A........B.#
# ###D#D#.#.###
#   #B#C#A#C#
#   #########
# ```
#
# 3: 7
# ```
# #############
# #AA.......B.#
# ###D#D#.#.###
#   #B#C#.#C#
#   #########
# ```
#
# 4: 600
# ```
# #############
# #AA.......B.#
# ###D#D#.#.###
#   #B#C#C#.#
#   #########
# ```
#
# 5: optimal double D = 15k
#
# ```
# #############
# #AA.......B.#
# ###.#.#.#D###
#   #B#C#C#D#
#   #########
# ```
#
# 6: 500
# ```
# #############
# #AA.......B.#
# ###.#.#C#D###
#   #B#.#C#D#
#   #########
# ```
#
# 7: double B:
# 60 + 60
# ```
# #############
# #AA.........#
# ###.#B#C#D###
#   #.#B#C#D#
#   #########
# ```
#
# 8: double A 3+3 = 6
# ```
# #############
# #...........#
# ###A#B#C#D###
#   #A#B#C#D#
#   #########
# ```
#
# 16282

# %% [markdown]
# ## Attempt 4
#
# - Currently optimal D and C = directly from room to room, no midway stops
# - B is +20 and A is +8 from if they didn't have to stop in hallway
# - After step 3, every move is into final room = optimal from that point on
#
# Start:
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #B#C#A#C#
#   #########
# ```
#
# 1: +8
#
# ```
# #############
# #.A.........#
# ###D#D#B#.###
#   #B#C#A#C#
#   #########
# ```
#
# 2: +40 = 48
#
# ```
# #############
# #.A.B.......#
# ###D#D#.#.###
#   #B#C#A#C#
#   #########
# ```
#
# 3: +5 = 53
# ```
# #############
# #.A.B.....A.#
# ###D#D#.#.###
#   #B#C#.#C#
#   #########
# ```
#
# 4: +600 = 653
#
# ```
# #############
# #.A.B.....A.#
# ###D#D#.#.###
#   #B#C#C#.#
#   #########
# ```
#
# 5: +7k = 7 653
#
# ```
# #############
# #.A.B.....A.#
# ###D#.#.#.###
#   #B#C#C#D#
#   #########
# ```
#
# 6: +500 = 8 153
#
# ```
# #############
# #.A.B.....A.#
# ###D#.#C#.###
#   #B#.#C#D#
#   #########
# ```
#
# 7: +30 = 8 183
#
# ```
# #############
# #.A.......A.#
# ###D#.#C#.###
#   #B#B#C#D#
#   #########
# ```
#
# 8: +8k = 16 183
#
# ```
# #############
# #.A.......A.#
# ###.#.#C#D###
#   #B#B#C#D#
#   #########
# ```
#
# 9: +50 = 16 233
#
# ```
# #############
# #.A.......A.#
# ###.#B#C#D###
#   #.#B#C#D#
#   #########
# ```
#
# 10: +3 = 16 236
#
# ```
# #############
# #.........A.#
# ###.#B#C#D###
#   #A#B#C#D#
#   #########
# ```
#
# 11: +8 = 16 244
#
# ```
# #############
# #...........#
# ###A#B#C#D###
#   #A#B#C#D#
#   #########
# ```
#
# = 16 244 ✅

# %% [markdown]
# ## Part 2
#
# > Add
# >
# >```
#   #D#C#B#A#
#   #D#B#A#C#
# >```
# >
# >between the two rows of amphies.

# %% [markdown]
# ## Attempt 1
#
# Start:
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #D#C#B#A#
#   #D#B#A#C#
#   #B#C#A#C#
#   #########
# ```
