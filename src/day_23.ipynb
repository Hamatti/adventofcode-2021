# %% [markdown]
# # Day 23 - Amphipod

# %% [markdown]
# Start:
#
# ```
# #############
# #...........#
# ###D#D#B#A###
#   #B#C#A#C#
#   #########
# ```
#
# Step 1: (9 energy)
#
# ```
# #############
# #A..........#
# ###D#D#B#.###
#   #B#C#A#C#
#   #########
# ```
#
# Step 2: (+300e = 309e)
#
# ```
# #############
# #A........C.#
# ###D#D#B#.###
#   #B#C#A#.#
#   #########
# ```
#
# Step 3: (+7000e = 7309e)
# ```
# #############
# #A........C.#
# ###D#.#B#.###
#   #B#C#A#D#
#   #########
# ```
#
# Step 4: (+8000e = 15309e)
# ```
# #############
# #A........C.#
# ###.#.#B#D###
#   #B#C#A#D#
#   #########
# ```
#
# Step 5: (+20e = 15329e)
# ```
# #############
# #A......B.C.#
# ###.#.#.#D###
#   #B#C#A#D#
#   #########
# ```
#
# Step 6: (+7e = 15336e)
# ```
# #############
# #AA.....B.C.#
# ###.#.#.#D###
#   #B#C#.#D#
#   #########
# ```
#
# Step 7: (+600e = 15936e)
# ```
# #############
# #AA.....B.C.#
# ###.#.#.#D###
#   #B#.#C#D#
#   #########
# ```
#
# Step 7: (+60e = 15996e)
# ```
# #############
# #AA.....B.C.#
# ###.#.#.#D###
#   #.#B#C#D#
#   #########
# ```
#
# Step 8: (+40e = 16036e)
# ```
# #############
# #AA.......C.#
# ###.#B#.#D###
#   #.#B#C#D#
#   #########
# ```
#
# Step 9: (+400e = 16436e)
# ```
# #############
# #AA.........#
# ###.#B#C#D###
#   #.#B#C#D#
#   #########
# ```
#
# Step 10: (+3e = 16439e)
# ```
# #############
# #A..........#
# ###.#B#C#D###
#   #A#B#C#D#
#   #########
# ```
#
# Step 11: (+3e = 16442e)
# ```
# #############
# #...........#
# ###A#B#C#D###
#   #A#B#C#D#
#   #########
# ```
